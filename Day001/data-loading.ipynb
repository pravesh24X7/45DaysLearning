# %% [markdown]
# ## 45 Days ML Journey - Day01
#
# ### Data Loading

# %%
# import necessary libs.

import numpy as np
import pandas as pd

# %% [markdown]
# ### Loading dataset from `https://raw.githubusercontent.com/rashida048/Datasets/master/titanic_data.csv`

# %%
df = pd.read_csv("https://raw.githubusercontent.com/rashida048/Datasets/master/titanic_data.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### Total no. of rows and columns in the above dataset.

# %%
print("Total rows: ", df.shape[0])
print("Total columns: ", df.shape[1])
# Out:
# Total rows:  891
# Total columns:  12

# %% [markdown]
# ### List all column name

# %%
print(df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ### Loading same dataset, this time from local excel file

# %%
df2 = pd.read_excel( r"C:\Users\hp\Downloads\titanic.xlsx", engine="openpyxl")
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1310 non-null   int64
#  1   survived   1310 non-null   int64
#  2   name       1310 non-null   object
#  3   sex        1310 non-null   object
#  4   age        1047 non-null   float64
#  5   sibsp      1310 non-null   int64
#  6   parch      1310 non-null   int64
#  7   ticket     1310 non-null   object
#  8   fare       1309 non-null   float64
#  9   cabin      296 non-null    object
#  10  embarked   1308 non-null   object
#  11  boat       487 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  746 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.4+ KB
# C:\ProgramData\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:85: UserWarning: Unknown extension is not supported and will be removed
# ...
