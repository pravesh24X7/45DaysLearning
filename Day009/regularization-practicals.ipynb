# %% [markdown]
# ## 45 Days ML Journey - Day009
# ### Regularization (Ridge and Lasso)

# %%
# import necessary libs.

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import Ridge

# %%
from sklearn.linear_model import Lasso, LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import fetch_california_housing

# %%
california_housing = fetch_california_housing(as_frame=True)
df = california_housing.data
y = california_housing.target
df.shape, y.shape
# Out:
# ((20640, 8), (20640,))

# %% [markdown]
# First we'll perform all the necessary preprocessing steps which we did before while learning Linear regression.
# <br/>
# These steps includes:
# 1. Removing `AvgBedrms` columns.
# 2. Performing `log` transformation on `MedInc`, `Population` and `target` columns.
# 3. Scaling operation on rest of the dataset.

# %%
print(df.columns)
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude'],
#       dtype='object')

# %%
df.drop(columns=['AveBedrms'], inplace=True)
df['MedInc'] = np.log1p(df["MedInc"])
df["Population"] = np.log1p(df["Population"])
y = np.log1p(y)
# Out:
# C:\Users\papsr\AppData\Local\Temp\ipykernel_8976\2098915556.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['AveBedrms'], inplace=True)
# C:\Users\papsr\AppData\Local\Temp\ipykernel_8976\2098915556.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MedInc'] = np.log1p(df["MedInc"])
# C:\Users\papsr\AppData\Local\Temp\ipykernel_8976\2098915556.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
std_scaler = StandardScaler()
X = std_scaler.fit_transform(df)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    random_state=42,
                                                    test_size=0.3)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((14448, 7), (6192, 7), (14448,), (6192,))

# %% [markdown]
# Frist we'll fit the normal regression model and check it's `RMSE` value.

# %%
simple_linear_regression = LinearRegression(n_jobs=-1)
simple_linear_regression.fit(X_train, y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
y_prediction_simple_linear_regression = simple_linear_regression.predict(X_test)

y_prediction_simple_linear_regression = np.expm1(y_prediction_simple_linear_regression)
y_test = np.expm1(y_test)
print("RMSE of Simple Linear Regression : ", mean_squared_error( y_test, y_prediction_simple_linear_regression )**0.5)
# Out:
# RMSE of Simple Linear Regression :  2.237846354901886e+63

# %% [markdown]
# Now, we'll try Ridge regression and check it's RMSE score.

# %%
l2_regularization = Ridge(alpha=10)
l2_regularization.fit(X_train, y_train)
# Out:
# Ridge(alpha=10)

# %%
y_predictions_l2_regularization = l2_regularization.predict(X_test)

y_predictions_l2_regularization = np.expm1(y_predictions_l2_regularization)
y_test = np.expm1(y_test)
print("RMSE of L2 Regularization : ", mean_squared_error(y_test, y_predictions_l2_regularization) ** 0.5)
# Out:
# C:\Users\papsr\anaconda3\envs\dl\lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: overflow encountered in expm1
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 5
#       3 y_predictions_l2_regularization = np.expm1(y_predictions_l2_regularization)
#       4 y_test = np.expm1(y_test)
# ----> 5 print("RMSE of L2 Regularization : ", mean_squared_error(y_test, y_predictions_l2_regularization) ** 0.5)
#
# File ~\anaconda3\envs\dl\lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# ...
